# %%
# Basic libraries
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# Model
from sklearn.linear_model import LogisticRegression

# Evaluation
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score, roc_curve

# Model Saving
import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("fab_energy_dataset_500-2.csv")

df.head()
# Out:
#          date tool_id process_type  wafers_processed  runtime_hours  \
# 0  01-01-2026      T4         Etch               156      19.356292
# 1  01-01-2026      T3   Deposition                51      18.663985
# 2  01-01-2026      T1   Deposition               285      10.276749
# 3  01-01-2026      T4  Lithography               113      15.601155
# 4  01-01-2026      T2         Etch                63      19.700768
#
#    idle_hours  cleanroom_temp   humidity  shift  energy_kwh
# 0    5.177951       21.783331  41.499624    Day      787.06
# 1    7.569869       20.003115  54.883173    Day      666.29
# 2    4.673423       21.599444  40.699985  Night     1044.23
# 3    7.019583       22.721230  46.757489  Night      833.80
# 4    3.132296       20.390688  50.263495  Night      618.01

# %%
df.shape
# Out:
# (500, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              500 non-null    object
#  1   tool_id           500 non-null    object
#  2   process_type      500 non-null    object
#  3   wafers_processed  500 non-null    int64
#  4   runtime_hours     500 non-null    float64
#  5   idle_hours        500 non-null    float64
#  6   cleanroom_temp    500 non-null    float64
#  7   humidity          500 non-null    float64
#  8   shift             500 non-null    object
#  9   energy_kwh        500 non-null    float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 39.2+ KB

# %%
df.describe()
# Out:
#        wafers_processed  runtime_hours  idle_hours  cleanroom_temp  \
# count        500.000000     500.000000  500.000000      500.000000
# mean         172.800000      15.972690    4.494852       22.004036
# std           72.506236       3.417729    2.069540        1.115659
# min           50.000000      10.045806    1.008657       20.003115
# 25%          108.000000      12.943922    2.611308       21.085599
# 50%          171.000000      15.821570    4.699990       22.028169
# 75%          236.000000      18.963818    6.228908       22.923356
# max          300.000000      21.992965    7.998024       23.990962
#
#          humidity  energy_kwh
# count  500.000000   500.00000
# mean    47.560978   907.88344
# std      4.397342   179.46540
# min     40.004988   455.07000
# 25%     43.819608   776.76000
# 50%     47.615616   901.35000
# 75%     51.412696  1044.56500
# max     54.965389  1347.51000

# %%
df.isnull().sum()
# Out:
# date                0
# tool_id             0
# process_type        0
# wafers_processed    0
# runtime_hours       0
# idle_hours          0
# cleanroom_temp      0
# humidity            0
# shift               0
# energy_kwh          0
# dtype: int64

# %%
df['process_type'].value_counts()
# Out:
# process_type
# Deposition     174
# Lithography    168
# Etch           158
# Name: count, dtype: int64

# %%
df['shift'].value_counts()
# Out:
# shift
# Day      264
# Night    236
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['energy_kwh'], kde=True)
plt.title("Energy Consumption Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='process_type', y='energy_kwh', data=df)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
threshold = df['energy_kwh'].median()

df['high_energy'] = np.where(df['energy_kwh'] > threshold, 1, 0)

# %%
df = df.drop(['date', 'energy_kwh'], axis=1)

# %%
le_tool = LabelEncoder()
le_process = LabelEncoder()
le_shift = LabelEncoder()

df['tool_id'] = le_tool.fit_transform(df['tool_id'])
df['process_type'] = le_process.fit_transform(df['process_type'])
df['shift'] = le_shift.fit_transform(df['shift'])

# %%
X = df.drop('high_energy', axis=1)
y = df['high_energy']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89        44
#            1       0.96      0.86      0.91        56
#
#     accuracy                           0.90       100
#    macro avg       0.90      0.91      0.90       100
# weighted avg       0.91      0.90      0.90       100

# %%
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.show()

# %%
y_prob = model.predict_proba(X_test)[:,1]
roc_auc = roc_auc_score(y_test, y_prob)

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

plt.plot(fpr, tpr, label="AUC="+str(round(roc_auc,2)))
plt.plot([0,1],[0,1],'--')
plt.legend()
plt.show()

# %%
pickle.dump(model, open("energy_model.pkl", "wb"))
pickle.dump(scaler, open("scaler.pkl", "wb"))
pickle.dump(le_tool, open("le_tool.pkl", "wb"))
pickle.dump(le_process, open("le_process.pkl", "wb"))
pickle.dump(le_shift, open("le_shift.pkl", "wb"))
